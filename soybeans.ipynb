# %%
# %cd /Users/adamszabunio/Desktop/granular_raw_data/2017_soil_model/01_raw-data-in/testing/soybean/
# %ls
# Out:
# /Users/adamszabunio/Desktop/granular_raw_data/2017_soil_model/01_raw-data-in/testing/soybean
# soybean_historical_yields_1970_1994.csv
# soybean_historical_yields_1995_2017.csv

# %%
import pandas as pd
soy_yields = pd.read_csv('soybean_historical_yields_1995_2017.csv', index_col=0)
print(soy_yields.shape)
soy_yields.head()
# Out:
# (33472, 7)
#    fips_code state_alpha  year  nassyield county_name         asd_desc  \
# 0       1033          AL  2016       31.2     COLBERT  NORTHERN VALLEY
# 1       1033          AL  2015       44.1     COLBERT  NORTHERN VALLEY
# 2       1033          AL  2014       44.0     COLBERT  NORTHERN VALLEY
# 3       1033          AL  2013       44.2     COLBERT  NORTHERN VALLEY
# 4       1033          AL  2012       44.0     COLBERT  NORTHERN VALLEY
#
#                        location_desc
# 0  ALABAMA, NORTHERN VALLEY, COLBERT
# 1  ALABAMA, NORTHERN VALLEY, COLBERT
# 2  ALABAMA, NORTHERN VALLEY, COLBERT
# 3  ALABAMA, NORTHERN VALLEY, COLBERT
# 4  ALABAMA, NORTHERN VALLEY, COLBERT

# %%
soy_y2 = pd.read_csv('soybean_historical_yields_1970_1994.csv', index_col=0)

soy_yields = soy_yields.append(soy_y2)
soy_yields.shape
# Out:
# (77462, 7)

# %%
ts_df = soy_yields.pivot(index='fips_code', columns='year', values='nassyield')
ts_df
# Out:
# year       1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...   \
# fips_code                                                              ...
# 1001       25.0  27.0  18.2  17.6  20.0  15.9  22.9  30.0  14.0  21.6  ...
# 1003       27.0  27.0  20.4  25.9  26.0  27.0  30.0  21.1  23.0  17.5  ...
# 1005       23.0  26.0  12.1  19.1  28.0  19.0  18.9  20.9  21.5  28.5  ...
# 1007       21.0  25.0  20.8  17.8  24.0  22.1  27.0  22.1  22.0  26.9  ...
# 1009       24.0  25.0  19.8  16.6  26.0  30.0  32.0  20.0  28.0  29.5  ...
# 1011       24.0  25.0  20.3  22.3  21.0  21.0  20.0  20.0  22.0  26.4  ...
# 1013       21.0  26.0  12.6  20.1  23.0  20.0  20.0  15.0  20.0  24.1  ...
# 1015       23.0  25.0  21.1  19.2  22.0  23.0  24.0  25.3  21.0  26.8  ...
# 1017       21.0  23.0  18.7  23.0  19.0  25.0  21.0  16.0  16.0   NaN  ...
# 1019       23.0  27.0  19.4  18.9  23.0  22.6  24.0  20.0  24.7  31.3  ...
# ...

# %%
pd.set_option('display.max_columns', 50)
ts_df.describe()
# Out:
# year          1970         1971         1972         1973         1974  \
# count  1450.000000  1446.000000  1715.000000  1752.000000  1810.000000
# mean     24.025517    25.230567    24.534111    24.653082    22.514641
# std       5.828479     5.894049     6.494447     5.224763     4.549158
# min       9.000000    10.000000     9.500000     8.000000     5.500000
# 25%      20.000000    22.000000    20.000000    21.000000    19.500000
# 50%      24.000000    25.000000    24.000000    24.000000    22.600000
# 75%      28.000000    29.000000    29.000000    28.000000    25.500000
# max      40.000000    41.000000    42.000000    40.000000    40.000000
#
# year          1975         1976         1977         1978         1979  \
# count  1784.000000  1781.000000  1829.000000  1848.000000  1872.000000
# mean     25.463397    23.341606    27.033461    26.040152    29.339476
# std       5.705164     6.693615     7.478861     7.032220     5.602669
# ...

# %%
# %matplotlib inline
ts_df.count().plot();

# %%
ts_df.T.describe()
# Out:
# fips_code      1001       1003       1005       1007       1009       1011   \
# count      27.000000  46.000000  21.000000  17.000000  39.000000  24.000000
# mean       21.374074  29.684783  22.895238  22.352941  27.120513  22.741667
# std         6.319664   7.188910   7.980193   2.834413   8.218566   7.732535
# min        11.800000  17.500000  12.100000  17.800000  14.400000  12.200000
# 25%        17.250000  25.150000  18.900000  20.800000  20.000000  19.825000
# 50%        21.600000  27.350000  20.900000  22.100000  26.000000  21.000000
# 75%        24.300000  34.750000  26.000000  24.300000  30.250000  23.250000
# max        41.200000  43.800000  52.100000  27.000000  49.700000  52.200000
#
# fips_code     1013       1015       1017       1019       1021       1023   \
# count      25.00000  44.000000  15.000000  46.000000  23.000000  17.000000
# mean       21.36400  25.625000  20.213333  26.330435  23.182609  23.723529
# ...

# %%
ts_df.T.count().plot(kind='hist', bins=100);

# %%
import seaborn as sns
sns.set()
