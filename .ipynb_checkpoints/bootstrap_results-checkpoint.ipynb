# %%
import pandas as pd
pd.set_option("display.max_columns", 999)

# %%
pd.read_csv("bootstrap_corn_metrics.csv", index_col=0)
# Out:
#                              MAE       MAPE       RMSE  RSQUARED       MAE1  \
# LR_PRED                13.588727  14.955182  20.200489  0.723817  12.938882
# FFILL_PRED             16.700000  23.020653  27.822514  0.476080  16.000000
# COUNTY_MEAN_PRED       18.598262  19.793846  27.545671  0.486454  17.943834
# EXP0.25_PRED           17.958265  19.016180  26.686450  0.517992  17.282471
# EXP0.5_PRED            16.967547  18.145158  25.656193  0.554491  16.352134
# EXP1_PRED              14.937767  16.041751  22.882208  0.645621  14.429842
# EXP2_PRED               9.654015  11.069598  15.469686  0.838030   9.305459
# EXP4_PRED               6.336511   8.354737  11.567892  0.909431   6.286615
# EXP8_PRED               6.323929   8.721130  12.164571  0.899847   6.689902
# EXP16_PRED              6.758611   9.355293  12.941411  0.886646   7.136711
# K1_PRED                 8.000000  10.746856  14.582172  0.856081   8.100000
# ...

# %%
preds_df = pd.read_csv("bootstrap_corn_predicitions.csv", index_col=0)
print(preds_df.shape)
preds_df.head()
# Out:
# (812, 84)
#            years  y_true    lr_pred  ffill_pred  county_mean_pred  \
# fips_code
# 1049        1985    96.2  67.831619        88.4        111.550314
# 1077        1978    66.4  50.293676        36.0         94.424906
# 1079        1993    65.6  86.226087       109.2         92.085967
# 1083        1974    40.0  45.019030        49.0         69.094724
# 1089        1971    51.0  39.948521        33.0         81.039125
#
#            exp0.25_pred  exp0.5_pred   exp1_pred   exp2_pred  exp4_pred  \
# fips_code
# 1049         111.155313   110.652535  109.086828  103.921851  99.964108
# 1077          93.724234    92.630137   88.815228   72.264867  52.337140
# 1079          92.913223    93.337729   93.040101   83.412325  66.669880
# 1083          69.225131    69.036554   67.567841   57.384043  46.795534
# 1089          80.499239    79.642194   76.304870   61.422044  46.518715
#
#             exp8_pred  exp16_pred  k1_pred  k2_mean_pred  k2_weighted_pred  \
# fips_code
# ...
